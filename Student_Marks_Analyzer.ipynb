# %%
import numpy as np

# %% [markdown]
# # Student Marks Analyzer
#
# This project uses NumPy to analyze student marks.
#
# ## Objectives
#
# - Calculate statistics
# - Find highest and lowest scores
# - Identify top performers
# - Practice NumPy aggregation functions

# %%
marks = np.array([
    78,
    65,
    92,
    88,
    45,
    56,
    99,
    72,
    81,
    69
])

# %%
marks
# Out:
# array([78, 65, 92, 88, 45, 56, 99, 72, 81, 69])

# %%
print(marks)
# Out:
# [78 65 92 88 45 56 99 72 81 69]

# %% [markdown]
# ##properties of marks

# %%
marks.shape
# Out:
# (10,)

# %%
marks.ndim
# Out:
# 1

# %%
marks.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ###statistics

# %%
np.average(marks)
# Out:
# np.float64(74.5)

# %%
np.mean(marks)
# Out:
# np.float64(74.5)

# %%
np.max(marks)
# Out:
# np.int64(99)

# %%
np.min(marks)
# Out:
# np.int64(45)

# %%
np.std(marks)
# Out:
# np.float64(15.75595125658873)

# %%
np.sort(marks)
# Out:
# array([45, 56, 65, 69, 72, 78, 81, 88, 92, 99])

# %%
marks[marks>80]
# Out:
# array([92, 88, 99, 81])

# %%
marks[-1:-3]
# Out:
# array([], dtype=int64)

# %%
marks[-1:-3:]
# Out:
# array([], dtype=int64)

# %%
marks[-3::]
# Out:
# array([72, 81, 69])

# %%
np.sort(marks)
# Out:
# array([45, 56, 65, 69, 72, 78, 81, 88, 92, 99])

# %%
marks
# Out:
# array([78, 65, 92, 88, 45, 56, 99, 72, 81, 69])

# %%
marks=np.sort(marks)

# %%
marks
# Out:
# array([45, 56, 65, 69, 72, 78, 81, 88, 92, 99])

# %%
marks[-3::]
# Out:
# array([88, 92, 99])

# %%
marks[marks>=40]
# Out:
# array([45, 56, 65, 69, 72, 78, 81, 88, 92, 99])

# %%
marks[marks>80]
# Out:
# array([81, 88, 92, 99])

# %%
print(marks[marks>80])
# Out:
# [81 88 92 99]

# %%
marks>80
# Out:
# array([False, False, False, False, False, False,  True,  True,  True,
#         True])

# %%
print(len.marks)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print(len.marks)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'marks'

# %%
np.sum(marks[marks>40])
# Out:
# np.int64(745)

# %%
np.sum(marks>40)
# Out:
# np.int64(10)

# %%
print(len(marks[marks>40]))
# Out:
# 10

# %%
marks[marks<90 and marks>60]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 marks[marks<90 and marks>60]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
